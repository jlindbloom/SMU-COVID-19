# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
import os
import sys

# %%
# Import data
df = pd.read_excel("raw_data.xlsx")

# %%
df.head()
# Out:
#   Campus Community Notified Date SMU was Notified of Positive Test  \
# 0                2020-08-28                             2020-08-27
# 1                2020-08-28                             2020-08-27
# 2                2020-08-28                             2020-08-27
# 3                2020-08-28                             2020-08-27
# 4                2020-08-28                             2020-08-27
#
#   Last Known Date on Campus                     Description  Active
# 0                2020-08-24  A student who lives off campus       1
# 1                2020-08-27  A student who lives off campus       1
# 2                2020-08-27   A student who lives on campus       1
# 3                2020-08-27   A student who lives on campus       1
# 4                2020-08-27  A student who lives off campus       1

# %% [markdown]
# # Active Cases

# %%
temp = df.copy()
temp_smu_dates = np.sort(temp["Date SMU was Notified of Positive Test"].unique())

# %%
counts = np.zeros(len(temp_smu_dates))
for i in range(len(temp_smu_dates)):
    sub_count = len(temp[temp["Campus Community Notified"] == temp_smu_dates[i]])
    counts[i] = sub_count

# %%
plt.figure(figsize=(10,5))
plt.fill_between(temp_smu_dates, np.cumsum(counts))
plt.title("SMU Cumulative Confirmed Cases")
plt.axvline(np.datetime64(dt.datetime.strptime("20-08-12", "%y-%m-%d")), ymin=0, c="k")
plt.axvline(np.datetime64(dt.datetime.now()), ymin=0, c="r")
plt.ylabel("# of Cases")
plt.savefig("cumulative_cases.png")

# %%
# Save dataframe.
d = {'Date': temp_smu_dates, 'Cases Reported to SMU': counts, "Cumulative Cases": np.cumsum(counts) }
d = pd.DataFrame(data=d)
d.to_csv("cleaned_case_data.csv", index=False)

# %%
# Daily new cases.
plt.figure(figsize=(10,5))
plt.scatter(temp_smu_dates, counts)
plt.title("SMU Cumulative Confirmed Cases")
plt.axvline(np.datetime64(dt.datetime.strptime("20-08-12", "%y-%m-%d")), ymin=0, c="k")
plt.axvline(np.datetime64(dt.datetime.now()), ymin=0, c="r")
plt.ylabel("# of Cases")
plt.savefig("daily_new_cases.png")

# %% [markdown]
# # Cumulative active.

# %%
temp = df[df["Active"] == 1]
temp_smu_dates = np.sort(temp["Date SMU was Notified of Positive Test"].unique())

# %%
temp
# Out:
#    Campus Community Notified Date SMU was Notified of Positive Test  \
# 0                 2020-08-28                             2020-08-27
# 1                 2020-08-28                             2020-08-27
# 2                 2020-08-28                             2020-08-27
# 3                 2020-08-28                             2020-08-27
# 4                 2020-08-28                             2020-08-27
# 5                 2020-08-28                             2020-08-27
# 6                 2020-08-28                             2020-08-27
# 7                 2020-08-28                             2020-08-27
# 8                 2020-08-28                             2020-08-27
# 9                 2020-08-28                             2020-08-27
# 10                2020-08-28                             2020-08-27
# 11                2020-08-28                             2020-08-27
# 12                2020-08-27                             2020-08-26
# 13                2020-08-27                             2020-08-26
# 14                2020-08-27                             2020-08-26
# 15                2020-08-27                             2020-08-27
# 16                2020-08-27                             2020-08-26
# 17                2020-08-27                             2020-08-26
# 18                2020-08-27                             2020-08-26
# 19                2020-08-27                             2020-08-26
# 20                2020-08-27                             2020-08-26
# 21                2020-08-27                             2020-08-26
# 22                2020-08-27                             2020-08-26
# 23                2020-08-26                             2020-08-26
# 24                2020-08-26                             2020-08-26
# 25                2020-08-26                             2020-08-25
# 26                2020-08-26                             2020-08-25
# 27                2020-08-26                             2020-08-25
# 28                2020-08-26                             2020-08-25
# 29                2020-08-26                             2020-08-25
# 30                2020-08-26                             2020-08-25
# 31                2020-08-26                             2020-08-25
# 32                2020-08-26                             2020-08-25
# 33                2020-08-26                             2020-08-23
# 34                2020-08-26                             2020-08-23
# 35                2020-08-26                             2020-08-22
# 36                2020-08-21                             2020-08-20
# 37                2020-08-20                             2020-08-20
# 38                2020-08-20                             2020-08-19
# 39                2020-08-20                             2020-08-19
# 40                2020-08-20                             2020-08-19
# 41                2020-08-20                             2020-08-19
# 42                2020-08-20                             2020-08-19
# 43                2020-08-18                             2020-08-17
#
#    Last Known Date on Campus                      Description  Active
# 0                 2020-08-24   A student who lives off campus       1
# 1                 2020-08-27   A student who lives off campus       1
# 2                 2020-08-27    A student who lives on campus       1
# 3                 2020-08-27    A student who lives on campus       1
# 4                 2020-08-27   A student who lives off campus       1
# 5                 2020-08-26   A student who lives off campus       1
# 6                 2020-08-27   A student who lives off campus       1
# 7                 2020-08-27   A student who lives off campus       1
# 8                 2020-08-27   A student who lives off campus       1
# 9                 2020-08-27   A student who lives off campus       1
# 10                2020-08-27    A student who lives on campus       1
# 11                2020-08-27    A student who lives on campus       1
# 12                2020-08-26   A student who lives off campus       1
# 13                2020-08-25   A student who lives off campus       1
# 14                2020-08-25    A student who lives on campus       1
# 15                2020-08-27   A student who lives off campus       1
# 16                2020-08-25   A student who lives off campus       1
# 17                2020-08-25    A student who lives on campus       1
# 18                2020-08-26   A student who lives off campus       1
# 19                2020-08-26   A student who lives off campus       1
# 20                2020-08-19    A student who lives on campus       1
# 21                2020-08-25    A student who lives on campus       1
# 22                2020-08-27    A student who lives on campus       1
# 23                2020-08-26    A student who lives on campus       1
# 24                2020-08-26   A student who lives off campus       1
# 25                2020-08-26    A student who lives on campus       1
# 26                2020-08-25   A student who lives off campus       1
# 27                2020-08-25    A student who lives on campus       1
# 28                2020-08-25   A student who lives off campus       1
# 29                2020-08-25   A student who lives off campus       1
# 30                2020-08-25    A student who lives on campus       1
# 31                2020-08-25    A student who lives on campus       1
# 32                2020-08-25   A student who lives off campus       1
# 33                2020-08-23    A student who lives on campus       1
# 34                2020-08-21    A student who lives on campus       1
# 35                2020-08-21   A student who lives off campus       1
# 36                2020-08-17  An employee who works on campus       1
# 37                2020-08-20    A student who lives on campus       1
# 38                2020-08-19    A student who lives on campus       1
# 39                2020-08-19    A student who lives on campus       1
# 40                2020-08-19    A student who lives on campus       1
# 41                2020-08-19    A student who lives on campus       1
# 42                2020-08-18   A student who lives off campus       1
# 43                2020-08-17    A student who lives on campus       1

# %%
counts = np.zeros(len(temp_smu_dates))
for i in range(len(temp_smu_dates)):
    sub_count = len(temp[temp["Campus Community Notified"] == temp_smu_dates[i]])
    counts[i] = sub_count

# %%
plt.figure(figsize=(10,5))
plt.fill_between(temp_smu_dates, np.cumsum(counts))
plt.title("SMU Cumulative Active Cases")
plt.axvline(np.datetime64(dt.datetime.now()), ymin=0, c="r")
plt.ylabel("# of Cases")
plt.savefig("cumulative_active_cases.png")

# %%
temp_smu_dates
# Out:
# array(['2020-08-17T00:00:00.000000000', '2020-08-19T00:00:00.000000000',
#        '2020-08-20T00:00:00.000000000', '2020-08-22T00:00:00.000000000',
#        '2020-08-23T00:00:00.000000000', '2020-08-25T00:00:00.000000000',
#        '2020-08-26T00:00:00.000000000', '2020-08-27T00:00:00.000000000'],
#       dtype='datetime64[ns]')
